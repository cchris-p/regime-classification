# %% [markdown]
# # What to start with (minimal viable set)
#
# * **For any pair**: policy rate, 2y yield, CPI core YoY (both countries), VIX, FX realized vol, FX returns.
# * Engineer: `rate_diff_2y`, `cpi_diff_core`, `rv_20d`.
# * Do: PELT on `rate_diff_2y` and `rv_20d`; 2-state HMM on `[ret, rv]`.
# * Combine with hard event dates (COVID, 2022 hikes).
# * Run MCPT per regime.

# %%
import pandas as pd

# %% [markdown]
# # 2-Year Yield Differential

# %% [markdown]
# NOTE: `rate_diff_2y` will be aggregated

# %%
from regime_partitioning.datasets.rate_diff_2y import (
    # Majors
    EURUSD_rate_diff_2y,
    USDJPY_rate_diff_2y,
    AUDUSD_rate_diff_2y,
    NZDUSD_rate_diff_2y,
    # Minors
    EURJPY_rate_diff_2y,
    EURAUD_rate_diff_2y,
    EURNZD_rate_diff_2y,
    AUDJPY_rate_diff_2y,
    NZDJPY_rate_diff_2y,
    AUDNZD_rate_diff_2y,
)

from regime_partitioning.datasets.cpi_diff_core import (
    # Majors
    EURUSD_cpi_diff_core,
    USDJPY_cpi_diff_core,
    AUDUSD_cpi_diff_core,
    NZDUSD_cpi_diff_core,
    # Minors
    EURJPY_cpi_diff_core,
    EURAUD_cpi_diff_core,
    EURNZD_cpi_diff_core,
    AUDJPY_cpi_diff_core,
    NZDJPY_cpi_diff_core,
    AUDNZD_cpi_diff_core,
)

# %%
EURNZD_cpi_diff_core.tail()
# Out:
# period
# 2025-04-30   -1.455490
# 2025-05-31   -1.872191
# 2025-06-30   -0.934842
# 2025-07-31   -1.239109
# 2025-08-31   -2.128508
# Freq: ME, Name: cpi_diff_core, dtype: float64

# %% [markdown]
# `rv_20d`

# %%
from regime_partitioning.datasets.rv_20d import rv_20d

eurusd_rv_20d = rv_20d("EURUSD", "2010-01-01", "2024-12-31")
